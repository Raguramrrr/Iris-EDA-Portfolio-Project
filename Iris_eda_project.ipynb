# %% [markdown]
# <a href="https://colab.research.google.com/github/Raguramrrr/Iris-EDA-Portfolio-Project/blob/main/Iris_eda_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #IRIS DATASET EDA PROJECT

# %% [markdown]
# #Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ###importing dataset

# %%
df=pd.read_csv("irisdataset.csv")
#top 5 rows
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#bottom 5 rows
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
#number of columns and rows
df.shape
# Out:
# (150, 5)

# %% [markdown]
# Insights:-
# There are 150 rows and 5 columns

# %%
#columns name
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Insights:-
#
# There are no Null values in irisdataset.

# %%
#stats information
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# insights:-
#
# Statistical information method
#
# 1.  Maximum stats is sepal_length in mean, Standard deviation in Petal_length, Minimum in sepal_length, maximum in sepal_length.
#
# 2. So, sepal have highest values in stats info.

# %% [markdown]
# #Data Preparation

# %% [markdown]
# ###null values

# %%
#checking null values
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# Insights:-
#
# 1. No null values

# %%
#drop duplicaates
df=df.drop_duplicates(keep='first')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
df.shape
# Out:
# (147, 5)

# %% [markdown]
# Insights:-
#
#
# > There are 147 rows and 5 columns. Because, we drop the duplicates values or keys in irisdataset.

# %% [markdown]
# ####sorting value

# %%
df_sort=df.sort_values(by='sepal_length', ascending=False)
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 41            4.5          2.3           1.3          0.3     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 42            4.4          3.2           1.3          0.2     Iris-setosa
# 38            4.4          3.0           1.3          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
#
# [147 rows x 5 columns]

# %%
df_sort=df.sort_values(by='petal_length', ascending=False)
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 22            4.6          3.6           1.0          0.2     Iris-setosa
#
# [147 rows x 5 columns]

# %%
df_sort=df.sort_values(by='sepal_width', ascending=False)
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species
# 15            5.7          4.4           1.5          0.4      Iris-setosa
# 33            5.5          4.2           1.4          0.2      Iris-setosa
# 32            5.2          4.1           1.5          0.1      Iris-setosa
# 14            5.8          4.0           1.2          0.2      Iris-setosa
# 16            5.4          3.9           1.3          0.4      Iris-setosa
# ..            ...          ...           ...          ...              ...
# 93            5.0          2.3           3.3          1.0  Iris-versicolor
# 68            6.2          2.2           4.5          1.5  Iris-versicolor
# 62            6.0          2.2           4.0          1.0  Iris-versicolor
# 119           6.0          2.2           5.0          1.5   Iris-virginica
# 60            5.0          2.0           3.5          1.0  Iris-versicolor
#
# [147 rows x 5 columns]

# %%
df_sort=df.sort_values(by='petal_length', ascending=False)
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 105           7.6          3.0           6.6          2.1  Iris-virginica
# 131           7.9          3.8           6.4          2.0  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 36            5.5          3.5           1.3          0.2     Iris-setosa
# 35            5.0          3.2           1.2          0.2     Iris-setosa
# 14            5.8          4.0           1.2          0.2     Iris-setosa
# 13            4.3          3.0           1.1          0.1     Iris-setosa
# 22            4.6          3.6           1.0          0.2     Iris-setosa
#
# [147 rows x 5 columns]

# %%
df_sort=df.sort_values(by='species', ascending=False)
df_sort
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 149           5.9          3.0           5.1          1.8  Iris-virginica
# 111           6.4          2.7           5.3          1.9  Iris-virginica
# 122           7.7          2.8           6.7          2.0  Iris-virginica
# 121           5.6          2.8           4.9          2.0  Iris-virginica
# 120           6.9          3.2           5.7          2.3  Iris-virginica
# ..            ...          ...           ...          ...             ...
# 30            4.8          3.1           1.6          0.2     Iris-setosa
# 29            4.7          3.2           1.6          0.2     Iris-setosa
# 28            5.2          3.4           1.4          0.2     Iris-setosa
# 27            5.2          3.5           1.5          0.2     Iris-setosa
# 0             5.1          3.5           1.4          0.2     Iris-setosa
#
# [147 rows x 5 columns]

# %% [markdown]
# #Feature Understanding

# %% [markdown]
# ###Histogram

# %%
sns.histplot(data=df, x='species',palette='gnuplot2_r', shrink=0.7)

# %% [markdown]
# Observations:-
#
#
# * Iris-setosa are approx values 46.4
# * Iris-versicolor species are approx values 49.5
# * Iris-Virginica are approx values 48.3

# %%
sns.histplot(data=df, x='sepal_length', kde=True)

# %%
sns.histplot(data=df, x='sepal_width', hue='species', multiple='stack')

# %%
sns.histplot(data=df, x='petal_width', y='petal_length')

# %% [markdown]
# ###KDEPLOT

# %%
sns.kdeplot(data=df, x='petal_length', hue='species', multiple='stack')

# %%
sns.kdeplot(data=df, x='sepal_length', hue='species', linewidth=5, palette='Blues')

# %%
sns.kdeplot(data=df, x='sepal_length', y='sepal_width', hue='species')

# %% [markdown]
# ###Boxplot

# %%
sns.boxplot(data=df)

# %%
sns.boxplot(x='sepal_length', y='species', data=df)

# %%
plt.figure(figsize=(20,7))
sns.boxplot(x='sepal_length', y='sepal_width', hue='species', data=df)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.boxplot(x='petal_length', y='petal_width', hue='species', data=df, palette='gnuplot2_r', showmeans=True)
plt.show()

# %% [markdown]
# #Feature Relationship

# %% [markdown]
# ###Scatterplot

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width')

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')

# %%
sns.scatterplot(data=df, x='petal_length', y='petal_width', hue='species', size='species', palette='GnBu')

# %% [markdown]
# ###Heatmap

# %%
dfpiv=df.pivot_table(index='sepal_length', columns='species', values='sepal_width')
dfpiv
# Out:
# species       Iris-setosa  Iris-versicolor  Iris-virginica
# sepal_length
# 4.3              3.000000              NaN             NaN
# 4.4              3.033333              NaN             NaN
# 4.5              2.300000              NaN             NaN
# 4.6              3.325000              NaN             NaN
# 4.7              3.200000              NaN             NaN
# 4.8              3.180000              NaN             NaN
# 4.9              3.050000         2.400000        2.500000
# 5.0              3.362500         2.150000             NaN
# 5.1              3.600000         2.500000             NaN
# 5.2              3.666667         2.700000             NaN
# 5.3              3.700000              NaN             NaN
# 5.4              3.660000         3.000000             NaN
# 5.5              3.850000         2.440000             NaN
# 5.6                   NaN         2.820000        2.800000
# 5.7              4.100000         2.820000        2.500000
# ...

# %%
sns.heatmap(dfpiv)

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109321      0.871305     0.817058
# sepal_width      -0.109321     1.000000     -0.421057    -0.356376
# petal_length      0.871305    -0.421057      1.000000     0.961883
# petal_width       0.817058    -0.356376      0.961883     1.000000

# %% [markdown]
# *Insights:-
#
# pandas.corr will give me back the 1.00000-by-0.87130 correlation matrix and it's time performance is fine for my application.

# %%
corr=df.corr()
fig, ax=plt.subplots(figsize=(10,5))
sns.heatmap(corr, annot=True, ax=ax)

# %% [markdown]
# ###Pairplot

# %%
sns.pairplot(data=df, diag_kind='kde', hue='species')

# %%
sns.pairplot(data=df, kind='reg', palette='rocket')

# %%
sns.pairplot(data=df, x_vars=['sepal_width', 'petal_length', 'petal_width'], y_vars=['sepal_length'], diag_kind=None)

# %%
g = sns.pairplot(df, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")

# %% [markdown]
# #Feature Scaling

# %% [markdown]
# ###Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %% [markdown]
# LabelEncoder can be used to normalize labels. It can also be used to transform non-numerical labels to numerical labels. Fit label encoder.

# %%
df['species']=le.fit_transform(df['species'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# Train and teat split

# %%
from sklearn.model_selection import train_test_split
X=df.drop(columns=['species'])
Y=df['species']
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.33)

# %% [markdown]
# #Model Training

# %% [markdown]
# ###Logistic Regression

# %%
#l=Logistic Regression
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Accuracy:", model.score(x_test, y_test)*100)
# Out:
# Accuracy: 95.91836734693877

# %% [markdown]
# ###KNeighbors Algorithms

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:", model.score(x_test, y_test)*100)
# Out:
# Accuracy: 91.83673469387756

# %% [markdown]
# ###DecisionTree Algorithms

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:", model.score(x_test, y_test)*100)
# Out:
# Accuracy: 95.91836734693877

# %% [markdown]
# #Final Insights:-
#
# 1. In iris dataset non null values. stats model Maximum values have sepal_length only.
# 2. And we Have drop duplicates values.
# 3. Species column iris-vsericolor have highest values in dataset.
# 4. correlation will give me back the 1.00000-by-0.87130 correlation matrix and it's time performance is fine for my application.
# 5. LabelEncoder can be used to normalize labels. It can also be used to transform non-numerical labels to numerical labels.
# 6. Machine learning model:-
#     * Logistic Regreesion model score is 95.9%
#     * KNeightbors Classifier model score is 91.8%
#     * Decision Classifier model score is 95.9%
